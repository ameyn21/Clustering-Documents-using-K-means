# %% [markdown]
# ## **Finding and analysing the various clusters in the internshala job listing**

# %% [markdown]
# ### **Import neccesary libraries**

# %%
from gensim.models import Word2Vec, Doc2Vec
import nltk 
import numpy as np 
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd
from sklearn.cluster import KMeans 
from sklearn import cluster
from sklearn.neighbors import KDTree
from sklearn import metrics 
from sklearn.decomposition import PCA 
from scipy.cluster import hierarchy 
from sklearn.cluster import AffinityPropagation
import re
from wordcloud import WordCloud, ImageColorGenerator
from itertools import cycle;

# %% [markdown]
# ### **Download NLTK stop words list**

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ### **Upgrade packages if needed**

# %%
# !pip install gensim --upgrade
# !pip install nltk  --upgrade
# !pip install numpy --upgrade
# !pip install scikit-learn --upgrade
# !pip install scipy --upgrade
# !pip install matplotlib --upgrade

# %% [markdown]
# ### **Upload dataset to Google Collab**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c66253a3-2bba-411a-9e33-5749db9a09e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c66253a3-2bba-411a-9e33-5749db9a09e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Job_Scrapping_Internshala_.xlsx to Job_Scrapping_Internshala_.xlsx

# %% [markdown]
# ### **Import the dataset**

# %%
import io
df_jobs = pd.read_excel(io.BytesIO(uploaded['Job_Scrapping_Internshala_.xlsx']))
# Dataset is now stored in a Pandas Dataframe

# %%
df_jobs.head()
# Out:
#    Unnamed: 0  ...                                        description
# 0           1  ...  Selected intern's day-to-day responsibilities ...
# 1           2  ...  Selected intern's day-to-day responsibilities ...
# 2           3  ...  Selected intern's day-to-day responsibilities ...
# 3           4  ...  Selected intern's day-to-day responsibilities ...
# 4           5  ...  Selected intern's day-to-day responsibilities ...
#
# [5 rows x 6 columns]

# %% [markdown]
# ### **Perform some pre-processing steps on the data**

# %%
# pre process the test.
stop_words = set(stopwords.words("english"))
def normalize_text(text):
    text = re.sub("Selected intern's day-to-day responsibilities include:", "", text["description"])    # remove common string from all jobs 
    regex = r"(\d(?:\.|\))\s+)|([a-z]\)\s+)|(•\s+)|([A-Z]\.\s+)|((?:[IVX]|[ivx])+(?:\.|\))\s+)"
    text = text.strip().replace("\n","").lower()     # convert to lowercase
    text = re.sub(regex, "", text)                   # remove all bullet points
    words = text.split()                             # Filter out any stop words
    text_without_stops = ""
    for word in words:
      if not word in stop_words:
        text_without_stops = text_without_stops + word + " "
    return text_without_stops

# %%
df_jobs['description_'] = df_jobs.apply(lambda row: normalize_text(row),axis=1)

# %% [markdown]
# ### **Tokenize the job descriptions**

# %%
# build word2vec model
wpt = nltk.WordPunctTokenizer()
tokenized_corpus = [wpt.tokenize(df_jobs['description_'][ind]) for ind in df_jobs.index]

# %% [markdown]
# ### **Build the Worde2Vec model to vectorize the job descriptions**

# %%
# Set values for various parameters
feature_size = 10    # Word vector dimensionality  
window_context = 10          # Context window size                                                                                    
min_word_count = 1   # Minimum word count                        
sample = 1e-3   # Downsample setting for frequent words

w2v_model = Word2Vec(tokenized_corpus, size=feature_size, 
                              window=window_context, min_count = min_word_count,
                              sample=sample, iter=100)

# %% [markdown]
# #### **Utility methods to find the vectors of the job description**

# %% [markdown]
# ##### We will find the word vectors of all the words in the job description and average them out to find the vector for the job description

# %%
def average_word_vectors(words, model, vocabulary, num_features):
    
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.
    
    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model[word])
    
    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
        
    return feature_vector
    
   
def averaged_word_vectorizer(corpus, model, num_features):
    vocabulary = set(model.wv.index2word)
    features = [average_word_vectors(tokenized_sentence, model, vocabulary, num_features)
                    for tokenized_sentence in corpus]
    return np.array(features)

# %%
# get document level embeddings
w2v_feature_array = averaged_word_vectorizer(corpus=tokenized_corpus, model=w2v_model,
                                             num_features=feature_size)
pd.DataFrame(w2v_feature_array)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
#             0         1         2  ...         7         8         9
# 0    0.833039  1.018772  0.105645  ...  0.501712  1.411814 -0.739154
# 1   -0.644235  2.350671 -0.059463  ...  0.882174  0.375437 -0.759926
# 2   -0.488653  1.839386  0.668712  ...  1.014242  0.564563 -1.060264
# 3   -1.644636  4.008578  1.243873  ...  0.664909  0.604857 -0.966011
# 4    2.164815 -0.316237  1.253066  ... -0.542153 -1.177079 -2.536367
# ..        ...       ...       ...  ...       ...       ...       ...
# 158  1.473865  1.752997  1.320946  ...  0.483953 -0.292301 -0.401930
# 159  1.187538  0.988615  0.214181  ...  0.374219  1.054210 -0.385045
# 160  2.219677  0.082682  0.082817  ...  0.890938  0.762010 -1.025321
# 161  1.865390  0.479141 -0.092931  ... -0.288366  0.350850 -0.410796
# 162  0.844542  1.215472  0.990708  ... -0.445052  1.116367 -0.160786
#
# [163 rows x 10 columns]

# %% [markdown]
# **Clustering using AffinityProagation**

# %%
ap = AffinityPropagation( )
ap.fit(w2v_feature_array)
cluster_labels = ap.labels_
cluster_labels = pd.DataFrame(cluster_labels, columns=['ClusterLabel_Aff_Prop'])
df_jobs_clustered = pd.concat([df_jobs, cluster_labels], axis=1)

# %%
df_jobs_clustered.head()
# Out:
#    Unnamed: 0  ... ClusterLabel_Aff_Prop
# 0           1  ...                     0
# 1           2  ...                     2
# 2           3  ...                     7
# 3           4  ...                     3
# 4           5  ...                    17
#
# [5 rows x 8 columns]

# %% [markdown]
# **As can be seen, the "AffinityPropagation" algorithm has found 17 clusters automatically. If this number seems high, we can adjust the hyperparamter "preferences" in the model**

# %% [markdown]
# **Clustering using Kmeans**

# %% [markdown]
# #### **Lets find the numbers of clusters using Kmeans**

# %%
import matplotlib.pyplot as plt
wcss = [] 

for i in range(1, 20): 
  kmeans = KMeans(n_clusters=i, init = 'k-means++', random_state = 42 ) 
  kmeans.fit(w2v_feature_array) 
  wcss.append(kmeans.inertia_) 

plt.plot(range( 1,20), wcss) 
plt.title( 'The Elbow Method' ) 
plt.xlabel('Number of clusters') 
plt.ylabel('WCSS') 
plt.show()

# %% [markdown]
# **There no clear elbow formed which specify the cluster number. Lets go ahead with "17" which was predicted by the AffinityPropagation algorithm.**

# %%
kmeans_clustering = KMeans(n_clusters = 17, init='k-means++');
idx = kmeans_clustering.fit_predict(w2v_feature_array)

# %%
cluster_labels_kmeans = pd.DataFrame(idx, columns=['ClusterLabel_kmeans'])
df_jobs_clustered_kmeans = pd.concat([df_jobs_clustered, cluster_labels_kmeans], axis=1)

# %%
df_jobs_clustered_kmeans.head()
# Out:
#    Unnamed: 0  ... ClusterLabel_kmeans
# 0           1  ...                   2
# 1           2  ...                   9
# 2           3  ...                  16
# 3           4  ...                   9
# 4           5  ...                   0
#
# [5 rows x 9 columns]

# %% [markdown]
# ### **Wordcloud for each cluster**

# %%
centers = kmeans_clustering.cluster_centers_
clusters = idx
centroid_map = dict(zip(w2v_model.wv.index2word, clusters));

# %% [markdown]
# #### **Get top 20 words in each cluster (20 words closest to the centroid)**

# %%
def get_top_words(index2word, k, centers, wordvecs):
    tree = KDTree(wordvecs);

    #Closest points for each Cluster center is used to query the closest 20 points to it.
    closest_points = [tree.query(np.reshape(x, (1, -1)), k=k) for x in centers];
    closest_words_idxs = [x[1] for x in closest_points];

    #Word Index is queried for each position in the above array, and added to a Dictionary.
    closest_words = {};
    for i in range(0, len(closest_words_idxs)):
        closest_words['Cluster #' + str(i).zfill(2)] = [index2word[j] for j in closest_words_idxs[i][0]]

    #A DataFrame is generated from the dictionary.
    df = pd.DataFrame(closest_words);
    df.index = df.index+1

    return df;

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
top_words = get_top_words(w2v_model.wv.index2word, 20, centers, w2v_feature_array);

# %%
top_words
# Out:
#       Cluster #00  Cluster #01     Cluster #02    Cluster #03  Cluster #04  \
# 1          manage    designing      functional   stakeholders        power
# 2              to      quality        research        project  statistical
# 3           learn      results         prepare        analyze        apply
# 4           apply    technical         working          users     concepts
# 5           based         test     engineering         mining     business
# 6        concepts         well  implementation              .     internal
# 7           solve         code       computing              &      improve
# 8        internal        power               ,         vision         team
# 9            work       design   opportunities         create         test
# 10            web   tensorflow     development       training      network
# 11  opportunities  statistical      algorithms              '         deep
# 12       research   developing           based  visualization     research
# 13        improve         deep           power   requirements      quality
# 14    statistical      develop        software           data           to
# 15       software           us           tools           need        solve
# 16        network     advanced     requirement        product    preparing
# 17          power   activities       gathering     annotation     projects
# 18      gathering       skills          design       patterns            (
# 19          teams          new     statistical          large   functional
# 20      preparing     internal        internal     technology    designing
#
#       Cluster #05       Cluster #06  Cluster #07  Cluster #08    Cluster #09  \
# 1        patterns        strategies  application        using              &
# 2           image            system  maintaining      include       training
# 3    requirements            neural       issues      clients      analyzing
# 4               :          required      solving         deep       identify
# 5         process           related           ml         code      processes
# 6    intelligence           reports        needs   algorithms          large
# 7              us             model      clients        write              '
# 8      techniques          learning          cnn          cnn              .
# 9         prepare          problems       across  information           data
# 10  visualization  responsibilities      include        tools        product
# 11              ,        processing         deep       across              -
# 12              -               etc         code    computing           need
# 13              /             solve       design       design  visualization
# 14      databases             teams        write      working      databases
# 15         pandas                to    knowledge     research         market
# 16      implement          business           us      problem     annotation
# 17      analyzing            market        using  application       students
# 18           data          students   algorithms        needs         pandas
# 19         create        conducting       skills         test       patterns
# 20         handle          networks     handling  statistical          image
#
#        Cluster #10   Cluster #11    Cluster #12     Cluster #13  \
# 1             sets      advanced     understand          across
# 2         customer  intelligence       industry          skills
# 3          machine     solutions        testing          design
# 4           trends      selected     technology     researching
# 5          process      students           data          models
# 6                ,       sources          image        analysis
# 7                /        handle        product            code
# 8       techniques       prepare       analysis               :
# 9                -       support              &        handling
# 10         prepare    management   requirements      developing
# 11        patterns     designing      databases     application
# 12             new        models     management       technical
# 13        selected        design  visualization       designing
# 14          handle         tools              :         working
# 15     requirement     technical             us           image
# 16  implementation          well     performing              us
# 17    requirements       quality     tensorflow  implementation
# 18        students         using       training          online
# 19        software          code         skills            well
# 20   visualization         solve        quality       computing
#
#       Cluster #14   Cluster #15       Cluster #16
# 1         science         excel            python
# 2               s      building            market
# 3           learn         write            trends
# 4            team        client               new
# 5        business       systems                 -
# 6           teams      multiple             large
# 7           solve       clients               etc
# 8         company       various          students
# 9        creating       include          training
# 10            new     different         databases
# 11          apply      computer        processing
# 12             to           cnn         analyzing
# 13     activities         using          networks
# 14       projects       improve           process
# 15       internal  implementing        annotation
# 16         intern          user           network
# 17    statistical     gathering          internal
# 18        network      research  responsibilities
# 19        develop    functional             teams
# 20  opportunities         needs                ai

# %%
def display_cloud(cluster_num, cmap):
  wc = WordCloud(background_color="black", max_words=2000, max_font_size=80, colormap=cmap);
  wordcloud = wc.generate(' '.join([word for word in top_words['Cluster #' + str(cluster_num).zfill(2)]]))
  plt.figure()
  plt.imshow(wordcloud)
  plt.axis("off")
  #plt.savefig('cluster_' + str(cluster_num), bbox_inches='tight')

# %%
cmaps = cycle([
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg', 'hsv',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar'])
for i in range(17):
    col = next(cmaps);
    display_cloud(i, col)

# %% [markdown]
# ### **Find average stipend of the clusters**

# %% [markdown]
# #### **Feature engineer "Stipend"**

# %% [markdown]
# The "salary" column is having below mentioned values which are improper.
#
# *   25000 /month
# *   8000-10000 /month
# *   Unpaid
# *   2000 /month + Incentives
# *   10000-15000 lump sum
# *   2000 + Incentives
#
# We need to clean this feature and convert it to float.
#
# We will exclude the incentives and the lump sum concepts and consider the given salaries as stipend's per month.
#
# Lets also strip unwanted texts from the values

# %%
df_jobs_clustered_kmeans['salary'] = df_jobs_clustered_kmeans['salary'].str.replace(' /month', '')
df_jobs_clustered_kmeans['salary'] = df_jobs_clustered_kmeans['salary'].str.replace(' /month + Incentives', '')
df_jobs_clustered_kmeans['salary'] = df_jobs_clustered_kmeans['salary'].str.replace('Incentives', '')
df_jobs_clustered_kmeans['salary'] = df_jobs_clustered_kmeans['salary'].str.replace('+', '')
df_jobs_clustered_kmeans['salary'] = df_jobs_clustered_kmeans['salary'].str.replace(' lump sum', '')
df_jobs_clustered_kmeans['salary'] = df_jobs_clustered_kmeans['salary'].str.replace('Unpaid', '0')

# %% [markdown]
# Some salaries are specified as a range. Lets average out this range to get a single float stipend value

# %%
def clean_salary_cal_average(x):
  print(x)
  if isinstance(x, str):
    if "-" in x:
      print(x)
      num1 = x.split('-')[0] 
      num2 = x.split('-')[1]
      x = ((float(num1) + float(num2))/2)
  return x

# %%
# creating of a new feature "stipend" which is the average value in case of a range.
df_jobs_clustered_kmeans['stipend'] = df_jobs_clustered_kmeans['salary'].apply(clean_salary_cal_average).astype('float')

# %%
# replace rows having stipend as 0 with mean
df_jobs_clustered_kmeans['stipend'] = df_jobs_clustered_kmeans['stipend'].replace(0, df_jobs_clustered_kmeans['stipend'].mean())

# %%
df_jobs_clustered_kmeans.head()
# Out:
#    Unnamed: 0                                       job_title  \
# 0           1  Machine Learning Model Building (For OCR Tool)
# 1           2                                   Deep Learning
# 2           3                                Machine Learning
# 3           4                                Machine Learning
# 4           5                                   Communication
#
#                    company_name        location     salary  \
# 0                    IIT Bombay          Mumbai  3000-5000
# 1                    IIT Bombay  Work From Home  2000-4000
# 2  Getboarded Technologies, LDA  Work From Home       2000
# 3         TorqueVision Labs LLC          Indore       5000
# 4    India Sanitation Coalition           Delhi      10000
#
#                                          description  \
# 0  Selected intern's day-to-day responsibilities ...
# 1  Selected intern's day-to-day responsibilities ...
# 2  Selected intern's day-to-day responsibilities ...
# 3  Selected intern's day-to-day responsibilities ...
# 4  Selected intern's day-to-day responsibilities ...
#
#                                         description_  ClusterLabel_Aff_Prop  \
# 0  work data cleaning, pre-processing, image coll...                      0
# 1  conducting research implementing machine learn...                      2
# 2  working code compliance python, numpy, tensorf...                      7
# 3  working computer vision, deep learning, machin...                      3
# 4  support isc secretariat conducting execution a...                     17
#
#    ClusterLabel_kmeans  stipend
# 0                    2   4000.0
# 1                    9   3000.0
# 2                   16   2000.0
# 3                    9   5000.0
# 4                    0  10000.0

# %% [markdown]
# **The average of stipend of all clusters is mentioned below**

# %%
df_jobs_clustered_kmeans.groupby(['ClusterLabel_kmeans'], as_index=False)['stipend'].mean()
# Out:
#     ClusterLabel_kmeans       stipend
# 0                     0   6893.662577
# 1                     1   7357.178571
# 2                     2   7720.588235
# 3                     3   5882.998247
# 4                     4   7500.000000
# 5                     5   6583.333333
# 6                     6   7272.750000
# 7                     7  10545.454545
# 8                     8   4750.000000
# 9                     9   7268.098773
# 10                   10   5000.000000
# 11                   11   8350.000000
# 12                   12   9350.000000
# 13                   13   4571.428571
# 14                   14   7200.000000
# 15                   15   8845.399182
# 16                   16  12640.082311

# %%
df_jobs_clustered_kmeans.to_csv("job_clustering.csv", encoding="utf-8")
